# %%
import matplotlib.font_manager as fm
for font in fm.fontManager.ttflist:
  print(font.name)
# Out:
# DejaVu Serif
# STIXGeneral
# DejaVu Sans Display
# DejaVu Serif
# DejaVu Sans
# STIXSizeTwoSym
# STIXGeneral
# cmtt10
# STIXSizeOneSym
# STIXSizeFourSym
# DejaVu Serif
# STIXSizeOneSym
# DejaVu Sans Mono
# STIXNonUnicode
# STIXGeneral
# cmss10
# STIXGeneral
# DejaVu Serif Display
# DejaVu Serif
# DejaVu Sans
# DejaVu Sans
# DejaVu Sans
# DejaVu Sans Mono
# DejaVu Sans Mono
# STIXSizeFiveSym
# STIXSizeFourSym
# STIXNonUnicode
# STIXSizeThreeSym
# cmmi10
# cmb10
# STIXNonUnicode
# cmex10
# STIXNonUnicode
# STIXSizeThreeSym
# STIXSizeTwoSym
# cmr10
# DejaVu Sans Mono
# cmsy10
# Malgun Gothic
# HoloLens MDL2 Assets
# Georgia
# Javanese Text
# Microsoft PhagsPa
# Yu Gothic
# Arial
# Candara
# Sylfaen
# Cambria
# Ink Free
# NanumMyeongjo
# Cambria
# NewJumja
# Constantia
# NanumGothic
# Noto Sans KR
# SimSun
# Yu Gothic
# Corbel
# NanumSquare
# Arial
# Segoe UI
# S-Core Dream
# NanumGothic
# HCR Batang ExtB
# Microsoft Himalaya
# NanumSquare
# Candara
# Segoe UI
# THEFACESHOP INKLIPQUID
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import glob, os

# %%
def get_font_family():
    """
    시스템 환경에 따른 기본 폰트명을 반환하는 함수
    """
    import platform
    system_name = platform.system()

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # Linux(colab)
        # !apt-get install fonts-nanum -qq  > /dev/null
        # !fc-cache -fv

        import matplotlib as mpl
        mpl.font_manager._rebuild()
        findfont = mpl.font_manager.fontManager.findfont
        mpl.font_manager.findfont = findfont
        mpl.backends.backend_agg.findfont = findfont
        
        font_family = "NanumBarunGothic"
    return font_family

plt.rc("font", family=get_font_family())

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14144/1050275017.py in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/gdrive')
#
# ModuleNotFoundError: No module named 'google'

# %%
! sudo apt-get install tree

# %%
df_path='/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data'

# %%
fields=os.listdir(df_path)
fields
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14144/692357682.py in <module>
# ----> 1 fields=os.listdir(df_path)
#       2 fields
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: '/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data'

# %%
dfs=[]
for field in fields:
  f=f'{df_path}/{field}'
  print(field, f)
  df=pd.read_csv(f)
  dfs.append(df)
  print(os.path.isfile(f))
# Out:
# 지역별_지가변동률.csv /content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/지역별_지가변동률.csv
# True
# 국내건설수주액.csv /content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/국내건설수주액.csv
# True
# 주택건설인허가실적.csv /content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/주택건설인허가실적.csv
# True
# 주택매매가격지수(KB).csv /content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/주택매매가격지수(KB).csv
# True
# 주택전세가격지수(KB).csv /content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/주택전세가격지수(KB).csv
# True
# 미분양주택현황.csv /content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/미분양주택현황.csv
# True
# 유형별_주택월세통합가격지수.csv /content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/유형별_주택월세통합가격지수.csv
# ...

# %%
dfs
# Out:
# [     Unnamed: 0  전국[%]  서울[%]  부산[%]  대구[%]  인천[%]  광주[%]  대전[%]  울산[%]  \
#  0    2005-01-01  0.226  0.192  0.083  0.212  0.145  0.156  0.196  0.137
#  1    2005-02-01  0.184  0.140  0.065  0.208  0.208  0.080  0.206  0.153
#  2    2005-03-01  0.348  0.403  0.119  0.278  0.470  0.154  0.674  0.180
#  3    2005-04-01  0.525  0.725  0.151  0.258  0.751  0.159  0.917  0.149
#  4    2005-05-01  0.562  0.590  0.185  0.254  0.693  0.291  0.850  0.131
#  ..          ...    ...    ...    ...    ...    ...    ...    ...    ...
#  189  2020-10-01  0.294  0.375  0.337  0.265  0.295  0.277  0.375  0.138
#  190  2020-11-01  0.322  0.405  0.458  0.326  0.287  0.370  0.416  0.161
#  191  2020-12-01  0.343  0.437  0.444  0.387  0.295  0.389  0.417  0.180
#  192  2021-01-01  0.311  0.408  0.281  0.342  0.297  0.305  0.386  0.184
#  193  2021-02-01  0.311  0.418  0.289  0.321  0.284  0.235  0.363  0.177
#
#       세종[%]  경기[%]  강원[%]  충북[%]  충남[%]  전북[%]  전남[%]  경북[%]  경남[%]  제주[%]
# ...

# %% [markdown]
# df1=건축허가현황, df2=주택건설인허가실적, df3=주택매매가격지수, df4=주택전세가격지수, df5=지역별 지가변동률

# %%
df1=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/건축허가현황.csv')
df2=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/주택건설인허가실적.csv')
df3=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/주택매매가격지수(KB).csv')
df4=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/주택전세가격지수(KB).csv')
df5=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/지역별_지가변동률.csv')

# %% [markdown]
# 주택시장의 변화를 알아보기 위해서는 주택 건축허가의 연면적을 확인해야됨

# %%
print(df1.iloc[0])
print(df2.iloc[0])
print(df3.iloc[0])
print(df4.iloc[0])
print(df5.iloc[0])
# Out:
# Unnamed: 0        2000-08-01
# 연면적-철근·철골조[㎡]      3898712.0
# 연면적-조적조[㎡]          122063.0
# 연면적-목조[㎡]             5229.0
# 연면적-기타(자재별)[㎡]      287185.0
# 연면적-주거용[㎡]         1812355.0
# 연면적-상업용[㎡]         1088979.0
# 연면적-공업용[㎡]          687577.0
# 연면적-교육및사회용[㎡]            0.0
# 연면적-기타(용도별)[㎡]      724278.0
# 연면적-자재별[㎡]         4313189.0
# 연면적-용도별[㎡]         4313189.0
# 동수-철근·철골조[동수]         4319.0
# 동수-조적조[동수]            1216.0
# 동수-목조[동수]               58.0
# 동수-기타(자재별)[동수]        1078.0
# 동수-주거용[동수]            2905.0
# 동수-상업용[동수]            2008.0
# 동수-공업용[동수]             741.0
# 동수-교육및사회용[동수]            0.0
# 동수-기타(용도별)[동수]        1017.0
# 동수-자재별[동수]            6671.0
# 동수-용도별[동수]            6671.0
# Name: 0, dtype: object
# Unnamed: 0    2007-01-01
# 전국[호]            12038.0
# 부산[호]              455.0
# 충북[호]              188.0
# 충남[호]             1004.0
# 대구[호]              818.0
# 대전[호]               55.0
# 강원[호]              452.0
# 광주[호]             1022.0
# ...

# %%
#for i in range(1,5):
 # dfs(i)=df(i).rename({"Unnamed: 0":"년도"}, axis = 1)

# %%
df1=df1.rename({"Unnamed: 0":"년도"}, axis = 1)

df2=df2.rename({"Unnamed: 0":"년도"}, axis = 1)

df3=df3.rename({"Unnamed: 0":"년도"}, axis = 1)

df4=df4.rename({"Unnamed: 0":"년도"}, axis = 1)

df5=df5.rename({"Unnamed: 0":"년도"}, axis = 1)

# %%
df1=df1.groupby(['년도'])['연면적-주거용[㎡]'].sum()
df2_g=df2.groupby(['년도'])['대구[호]'].sum()
df3=df3.groupby(['년도'])['아파트(서울)[2019.01=100]'].sum()
df4=df4.groupby(['년도'])['아파트(서울)[2019.01=100]'].sum()
df5=df5.groupby(['년도'])['대구[%]'].sum()

# %%
plt.subplots(1, figsize=(20,6))
df1.plot(marker='')

# %% [markdown]
# ### 전국의 년도별 건축연면적당 인허가량은 금융위기인 2008년 하락한 인후 2016년 최고치를 달성한후 완만한 하향안정세를 보이고 있다.

# %%
plt.subplots(1, figsize=(20,6))
df2.plot(marker='')

# %% [markdown]
# ## 대구의 주택건설인허가 실적에따르면 계절적요인(겨울)으로 인해 건축허가량이 변하고 있음을 알 수 있다.

# %%
plt.subplots(1, figsize=(20,6))
df3.plot(marker='')

# %% [markdown]
# ### 2019년을 기준으로한 서울 아파트 총지수를 살펴보면 2021년 현재 약 20%이상 상승한것으로 보여진다. 허나 이것은 전체 평균을 한것으로 국지적인 가격 상승을 보여주고 있지는 않다.

# %%
df4
# Out:
# 년도
# 1986-01-01      9.782
# 1986-02-01     10.195
# 1986-03-01     10.550
# 1986-04-01     10.787
# 1986-05-01     10.875
#                ...
# 2020-11-01    110.216
# 2020-12-01    112.406
# 2021-01-01    114.116
# 2021-02-01    115.372
# 2021-03-01    116.295
# Name: 아파트(서울)[2019.01=100], Length: 423, dtype: float64

# %%
plt.subplots(1, figsize=(20,6))
df4.plot(marker='')

# %% [markdown]
# ### 2019년을 기준으로한 서울 아파트 전세가격 총지수를 살펴보면 매매가격 총지수와 같은 흐름을 보이고 있으며 IMF인 1998년 하락한 후 완만하게 상승하고 있음을 알 수 있다.

# %%
df5
# Out:
# 년도
# 2005-01-01    0.212
# 2005-02-01    0.208
# 2005-03-01    0.278
# 2005-04-01    0.258
# 2005-05-01    0.254
#               ...
# 2020-10-01    0.265
# 2020-11-01    0.326
# 2020-12-01    0.387
# 2021-01-01    0.342
# 2021-02-01    0.321
# Name: 대구[%], Length: 194, dtype: float64

# %%
fig, ax = plt.subplots(1, figsize=(60,10))
#ax.bar(a.index,a.iloc[:],width=1)
sns.barplot(df5.index,df5.iloc[:], ax=ax)
fig.autofmt_xdate(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 대구의 지가변동률을 살펴보면 2008년12월 금융위기 당시 -1.7% 하락한 후 2009년6월경 회복하기 시작하였으며 2013년을 기준으로 꾸준한 상승을 하였다.

# %%
df5.describe()
# Out:
# count    194.000000
# mean       0.231629
# std        0.215551
# min       -1.707000
# 25%        0.150000
# 50%        0.267000
# 75%        0.342000
# max        0.543000
# Name: 대구[%], dtype: float64

# %% [markdown]
# ### 대구의 지가는 평균상승률 0.23% 표준오차는 0.21%이며 최하 상승률은 -1.7%, 최고 상승률은 0.54%이다.

# %%
fig, ax = plt.subplots(1, figsize=(60,10))
#ax.bar(a.index,a.iloc[:],width=1)
sns.barplot(df2.index,df2.iloc[:], ax=ax)
fig.autofmt_xdate(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-f3b52be5349f> in <module>()
#       1 fig, ax = plt.subplots(1, figsize=(60,10))
#       2 #ax.bar(a.index,a.iloc[:],width=1)
# ----> 3 sns.barplot(df2.index,df2.iloc[:], ax=ax)
#       4 fig.autofmt_xdate(rotation=45)
#       5 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
# ...

# %% [markdown]
# ### 대구의 주택 건축인허가는 2017년 부터 증가하기 시작하였으며 건설공사의 특성상 인허가 시기와 완공시기와의 갭은 최소 3~5년정도가 필요하기에 2021년을 기점으로 완공이 많이 이루어질것으로 판단된다.

# %%
df2.describe()

# %% [markdown]
# ### 대구의 주택건설인허가 실적을 살펴보면 평균 8963세대이며 최소 25세대 최대 35444세대의 인허가가 있었음을 알수 있다. 이것은 계절적 요인에 따라 편차가 8146세대로 크게 나타나고있다.

# %%
df2.index

# %%
df1=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/건축허가현황.csv')
df2=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/주택건설인허가실적.csv')
df3=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/주택매매가격지수(KB).csv')
df4=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/주택전세가격지수(KB).csv')
df5=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/지역별_지가변동률.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14144/2354707396.py in <module>
# ----> 1 df1=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/건축허가현황.csv')
#       2 df2=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/주택건설인허가실적.csv')
#       3 df3=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/주택매매가격지수(KB).csv')
#       4 df4=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/주택전세가격지수(KB).csv')
#       5 df5=pd.read_csv('/content/gdrive/MyDrive/235724_한국 부동산 데이터 시각화 경진대회_data/지역별_지가변동률.csv')
#
# ...

# %%
df2_n = df2.set_index("Unnamed: 0", inplace=True)
df2_n

# %%
df2_n.head(3)

# %%
df2 = df2.rename({"Unnamed: 0":"년도"},axis=1)
col=["년도", "대구[호]"]
df2_dae = df2[col]
df2_dae

# %%
df2.set_index("Unnamed: 0", inplace=True)

# %%
a_2019 = 10
k = 2019
eval(f"a_{k}")

# %%
year = ["2019", "2020", "2021"]
a_2019=[]
a_2020=[]
a_2021=[]

for i in df2.index:
  for k in year:
    if k in i:
      eval(f"a_{k}").append(i)

# %%
for k in year[:1]:
  eval(f"df2_{k}") = df2.loc[eval(f"a_{k}")].T
  col = eval(f"df2_{k}").columns
  sum = 0
  for i in col:
    sum += eval(f"df2_{k}")[i]
  eval(f"df2_{k}")["sum_2019"] = sum

# %%
col=df2_2019.columns
col

# %%
df2_2019 = df2.loc[eval(f"a_{2019}")].T
df2_2020 = df2.loc[eval(f"a_{2020}")].T
df2_2021 = df2.loc[eval(f"a_{2021}")].T

# %%
col=df2_2019.columns
sum = 0
for i in col:
  sum += df2_2019[i]
df2_2019["sum_2019"] = sum
col=df2_2020.columns
sum = 0
for i in col:
  sum += df2_2020[i]
df2_2020["sum_2020"] = sum
col=df2_2021.columns
sum = 0
for i in col:
  sum += df2_2021[i]
df2_2021["sum_2021"] = sum

# %%
sum_df = pd.concat([df2_2019,df2_2020,df2_2021], axis=1).T

# %%
temp = []
for i in sum_df.index:
  if "sum" in i:
    temp.append(i)

sum_df.loc[temp][["대구[호]"]]

# %%
def returnName(s):
    indx=s.index("[")
    return s[:indx]

def df_to_pie(df):
    cols=df.columns
    ratio=df.loc[cols]
    labels=list(map(returnName,cols))
    size=len(ratio)
    
    explode=[0.15 for i in range(size)]
        
    ax.set_title(" 대구주택인허가현황") #타이틀
    ax.pie(ratio, labels=labels, autopct='%.0f%%', explode=explode, colors=sns.color_palette('pastel')[:17]) #설정

# %%
df_

# %%
df2_2019_p

# %%
df2_2019_p = df2_2019.T[["대구[호]"]].T.drop("sum_2019",axis=1)
df2_2019_p
df_to_pie(df2_2019_p.T)

# %%
fig, axes = plt.subplots(3,3,figsize=(18,18))
axes = axes.flatten()

for year, ax in zip(range(2013,2022),axes):
    df_to_pie(dfs2.loc[[str(year)+"-01-01"]],str(year)+"-01-01")

# %%
dfs2 = dfs[2].drop(["전국[호]","수도권[호]","파일"], axis=1)

# %%
fig, axes=plt.subplots(2,3,figsize=(16,10))
axes=axes.flatten()
for year,ax in zip(range(2019,2021),axes):
  ax.set_title(f'{year}년도')
  ax.pie(df2sum_df[year], labels=fields, autopct='%.1f%%')
