# %% [markdown]
# # ch05.09. 사이킷런 실습 - 회귀분석
#
# ---
# * 날짜: 2022-05-20
# * 이름: 고민수
#
# ## 학습내용
#     - 사이킷런을 이용해 여러가지 회귀 모델을 사용한다.
#     - 회귀 성능 지표에 대해 이해한다.
#     - 회귀 분석 결과를 시각화 한다.

# %% [markdown]
# ```
# import numpy as np
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# ```

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 단순 회귀 분석
# ---

# %% [markdown]
# ### **| 데이터 처리**

# %% [markdown]
# #### **주택 데이터 EDA**
#
# [https://archive.ics.uci.edu/ml/datasets/Housing](https://archive.ics.uci.edu/ml/datasets/Housing)
#
#
# <pre>
# 01. CRIM     도시의 인당 범죄율
# 02. ZN       2만 5,0000평방 피트가 넘는 주택 비율
# 03. INDUS    도시에서 소매 업종이 아닌 지역 비율
# 04. CHAS     찰스 강 인접 여부(강 주변=1, 그외=0)
# 05. NOX      일산화질소 농도(10ppm당)
# 06. RM       주택의 평균 방 개수
# 07. AGE      1940년 이전에 지어진 자가 주택 비율
# 08. DIS      다섯 개의 보스턴 고용 센터까지 가중치가 적용된 거리
# 09. RAD      방사형으로 뻗은 고속도로까지 접근성 지수
# 10. TAX      10만 달러당 재산세율
# 11. PTRATIO  도시의 학생-교사 비율
# 12. B        1000(Bk - 0.63)^2 도시의 아프리카계 미국인 비율
# 13. LSTAT    저소득층 비율
# 14. MEDV     자가 주택의 중간가격 (단위 $1000s)
# </pre>
#
# ```
# import pandas as pd
#
# df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
#                  'python-machine-learning-book-3rd-edition/'
#                  'master/ch10/housing.data.txt',
#                  header=None,
#                  sep='\s+')
#
# df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS',
#               'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#               'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
# ```

# %% [markdown]
# * 데이터 불러오기 및 기본 shape 확인

# %%
from sklearn.preprocessing import StandardScaler
def housing_loader():
    df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
                 'python-machine-learning-book-3rd-edition/'
                 'master/ch10/housing.data.txt',
                 header=None,
                 sep='\s+')

    df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 
              'NOX', 'RM', 'AGE', 'DIS', 'RAD', 
              'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
    # 단순 X : RM y : MEDV
    X = df['RM'].values
    y = df['MEDV'].values

    # 모델 라이브러리에서의 암묵적인 룰
    # 인풋 X는 2차 텐서 (행렬)
    # 아웃풋 y는 1차 텐서 (벡터) / 단, 세개 이상 카테고리면 행렬
    # X.shape = (506,1) , y.shape = (506,)

    # 방법 1 : 넘파이 reshape
    X = X.reshape(-1,1)

    # 방법 2 : 넘파이 배열 변환시
    X = df[ ['RM'] ].values
    
    # minmax / z-score
    sc_x = StandardScaler() # X에 대한 정규화 mean, std가 정해지지 않음
    sc_y = StandardScaler() # y에 대한 정규화 mean, std가 정해지지 않음
    sc_x.fit(X_train) # 인풋 X_train에 대한 mean, std 정해주기
    sc_y.fit(y_train.reshape(-1,1)) # 아웃풋 y_train에 대한 mean, std 정해주기
    # fit 함수의 인풋은 2차 텐서

    # sc_x 함수 : 데이터가 들어오면 x-maen_train / std_xtrain
    X_train = sc_x.fit_transform(X_train) # 데이터 변환
    y_train = sc_x.fit_transform(y_train.reshape(-1,1)).flatten() # 데이터 변환, flatten() : 1차원 배열로 나열해줌
    X_train.shape, y_train.shape
    X_test = sc_x.fit_transform(X_test) # 데이터 변환
    y_test = sc_x.fit_transform(y_test.reshape(-1,1)).flatten() # 데이터 변환, flatten() : 1차원 배열로 나열해줌
    X_test.shape, y_test.shape

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
                 'python-machine-learning-book-3rd-edition/'
                 'master/ch10/housing.data.txt',
                 header=None,
                 sep='\s+')

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 
              'NOX', 'RM', 'AGE', 'DIS', 'RAD', 
              'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# * 각 속성별 기본 정보 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# * 속성별 고유값 확인

# %%
for col in df.columns :
  print( col, len(df[col].unique()) )  # 각 피쳐의 고유값 개수
# Out:
# CRIM 504
# ZN 26
# INDUS 76
# CHAS 2
# NOX 81
# RM 446
# AGE 356
# DIS 412
# RAD 9
# TAX 66
# PTRATIO 46
# B 357
# LSTAT 455
# MEDV 229

# %% [markdown]
# * 속성별 분포 시각화

# %%
fig, axes = plt.subplots(2,7, figsize = (20,6))
axes = axes.flatten()

for col, ax in zip(df.columns, axes) :
  sns.histplot(data=df, x = col, ax = ax)

# %% [markdown]
# * 속성간 상관계수 시각화

# %%
plt.figure(figsize = (12,6))
sns.heatmap(df.corr(), annot = True, vmax = 1, vmin = -1, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# * 모든 속성간 산점도 그리기

# %%
sns.pairplot(data = df.sample(200))

# %% [markdown]
# #### **데이터 전처리**

# %% [markdown]
# * 넘파이 배열로 변환

# %%
# 단순 X : RM y : MEDV
X = df['RM'].values
y = df['MEDV'].values

# 모델 라이브러리에서의 암묵적인 룰
# 인풋 X는 2차 텐서 (행렬)
# 아웃풋 y는 1차 텐서 (벡터) / 단, 세개 이상 카테고리면 행렬
# X.shape = (506,1) , y.shape = (506,)

# 방법 1 : 넘파이 reshape
X = X.reshape(-1,1)

# 방법 2 : 넘파이 배열 변환시
X = df[ ['RM'] ].values

# %% [markdown]
# * 데이터 분할 (테스트 비율 0.2)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 1 )

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((404, 1), (102, 1), (404,), (102,))

# %% [markdown]
# * 스케일링 - 정규화 진행

# %%
from sklearn.preprocessing import StandardScaler
# minmax / z-score
sc_x = StandardScaler() # X에 대한 정규화 mean, std가 정해지지 않음
sc_y = StandardScaler() # y에 대한 정규화 mean, std가 정해지지 않음
sc_x.fit(X_train) # 인풋 X_train에 대한 mean, std 정해주기
sc_y.fit(y_train.reshape(-1,1)) # 아웃풋 y_train에 대한 mean, std 정해주기
# fit 함수의 인풋은 2차 텐서

# sc_x 함수 : 데이터가 들어오면 x-maen_train / std_xtrain
# Out:
# StandardScaler()

# %% [markdown]
# * 훈련 데이터 정규화

# %%
X_train = sc_x.fit_transform(X_train) # 데이터 변환
y_train = sc_x.fit_transform(y_train.reshape(-1,1)).flatten() # 데이터 변환, flatten() : 1차원 배열로 나열해줌
X_train.shape, y_train.shape
# Out:
# ((404, 1), (404,))

# %% [markdown]
# * 테스트 데이터 정규화

# %%
X_test = sc_x.fit_transform(X_test) # 데이터 변환
y_test = sc_x.fit_transform(y_test.reshape(-1,1)).flatten() # 데이터 변환, flatten() : 1차원 배열로 나열해줌
X_test.shape, y_test.shape
# Out:
# ((102, 1), (102,))

# %% [markdown]
# ### **| 모델링**

# %% [markdown]
# #### **직접 만든 회귀 클래스 사용**

# %% [markdown]
# * 클래스 구현

# %%
class LinearRegressionGD():
    
    def __init__(self, lr=0.001, random_state=1):
        self.lr=lr
        self.seed = np.random.RandomState(random_state)

    def init_weights(self, X):
        size = X.shape[1]
        self.w = self.seed.normal(0,0.01,size = size+1)

    def model(self, X):
        return np.dot(X, self.w[:-1]) + self.w[-1]

    def loss(self, y, y_hat):
        Loss = (y-y_hat)**2
        Loss = 1/2*np.sum(Loss)/ len(y) 
        return Loss

    def evaluate(self, X, y):
        y_hat = self.model(X)
        loss = self.loss(y, y_hat) # 손실평균
        return loss

    def fit(self, X, y, epochs=10, show_params=False):

        self.init_weights(X) # 가중치 초기화
        self.history=dict(loss=[]) # history 초기화

        for epoch in range(epochs):
            # 최적화
            y_hat = self.model(X)
            
            self.w[:-1] = self.w[:-1] + self.lr * np.dot(X.T , (y-y_hat))
            self.w[-1] = self.w[-1] + self.lr * np.sum(y-y_hat)

            # 평가 및 결과 저장
            loss = self.evaluate(X, y)
            self.history['loss'].append(loss)
            if show_params: print(self.w)
                
            # 100 iter 마다 cost 출력
            if epoch % 100 == 0:
                print(f'[Epoch {epoch}] loss: {np.round(loss,2)}')

    # 데이터 흐름 시각화
    def draw_dflow(self, X, y, title='', figsize=(8,4)):
        y_hat = self.model(X)
        
        plt.figure(figsize=figsize)
        plt.title(title)
        plt.plot(y, label='y', marker='o')
        plt.plot(y_hat, label='$\hat{y}$', marker='.', linestyle='--')
        plt.legend()
        plt.show()

    # 학습 곡선 시각화
    def draw_lcurve(self, title='', figsize=(8,4)):
        plt.figure(figsize=figsize)
        plt.title(title)
        plt.plot(self.history['loss'], label='loss', marker='o')
        plt.xlabel('epoch')
        plt.legend()
        plt.show()

# %% [markdown]
# * 모델 로드 및 학습

# %%
model = LinearRegressionGD(lr=0.001)
model.fit(X_train, y_train, 501)
# Out:
# [Epoch 0] loss: 0.35
# [Epoch 100] loss: 0.27
# [Epoch 200] loss: 0.27
# [Epoch 300] loss: 0.27
# [Epoch 400] loss: 0.27
# [Epoch 500] loss: 0.27

# %% [markdown]
# * 학습곡선 그리기

# %%
model.draw_dflow(X_train, y_train)

# %% [markdown]
# * 값 비교

# %%
model.draw_lcurve()

# %% [markdown]
# * 기울기와 절편 구하기
#
# \begin{align}
# \hat{y} = wx+b
# \end{align}

# %%
w = model.w[0]
b = model.w[-1]
print(f'기울기 : {w:.3f}')
print(f'절편 : {b:.3f}')
# Out:
# 기울기 : 0.671
# 절편 : 0.000

# %% [markdown]
# * 회귀선 시각화

# %%
plt.scatter(X_train, y_train, label= 'trainset', c='dodgerblue', edgecolor='k')
plt.scatter(X_test, y_test, label= 'testset', c='limegreen', edgecolor='k')
plt.plot(X_train,0.664*X_train, color='r', linestyle=':')  
plt.xlabel('Average number of rooms [RM] (standardized)')
plt.ylabel('Price in $1000s [MEDV] (standardized)')
plt.legend()
plt.show()

# %% [markdown]
# #### **사이킷런으로 추정**

# %% [markdown]
# * 모델 로드 및 학습

# %%
from sklearn.linear_model import *
linear = LinearRegression() # 모델 클래스 가져오기
linear.fit(X_train, y_train) # 학습
# Out:
# LinearRegression()

# %% [markdown]
# * 기울기와 절편 구하기
#
# \begin{align}
# \hat{y} = wx+b
# \end{align}

# %%
w = linear.coef_[0] # 계수 = 가중치
b = linear.intercept_ # 절편 = 편향(bias)

print(f'기울기 : {w}')
print(f'절편 : {b:.3f}')
# Out:
# 기울기 : 0.6709633342696334
# 절편 : 0.000

# %% [markdown]
# * 회귀선 시각화

# %%
plt.scatter(X_train, y_train, label= 'trainset', c='dodgerblue', edgecolor='k')
plt.scatter(X_test, y_test, label= 'testset', c='limegreen', edgecolor='k')
plt.plot(X_train,w*X_train, color='r', linestyle=':')  
plt.xlabel('Average number of rooms [RM] (standardized)')
plt.ylabel('Price in $1000s [MEDV] (standardized)')
plt.legend()
plt.show()

# %% [markdown]
# #### **RANSAC을 사용한 안정된 회귀모델 훈련**
#
# - RANSAC (RANdom SAmple Consensus)
# - 이상치를 효율적으로 다루는 알고리즘
# - 이상치를 제거하는 대신 정상치(inlier) 라는 일부 데이터로 회귀 모델을 훈련
#
# ```
# 1. 랜덤하게 일부 샘플을 정상치로 선택하여 모델 훈련
# 2. 훈련된 모델에서 다른 모든 포인트를 테스트하여 사용자가 입력한 허용 오차 안에 속한 포인트를 정상치에 추가
# 3. 모든 정상치를 사용하여 모델을 재훈련
# 4. 훈련된 모델과 정상치 간의 오차 추정
# 5. 성능이 사용자가 지정한 임계 값에 도달하거나 지정된 반복 횟수에 도달하면 알고리즘 종료
# ```

# %% [markdown]
# * 모델 로드 및 훈련

# %%
ransac = RANSACRegressor( LinearRegression(), # 사용할 모델
                         max_trials = 100,   # 최대 반복 횟수
                         min_samples = 50,   # 랜덤하게 선택할 샘플의 최소 개수
                         loss = 'squared_error', # 오차제곱 {absolute_error}
                         random_state = 1
                         )    
ransac.fit(X_train, y_train)
# Out:
# RANSACRegressor(base_estimator=LinearRegression(), loss='squared_error',
#                 min_samples=50, random_state=1)

# %% [markdown]
# * 학습 파라미터 확인

# %%
w = ransac.estimator_.coef_[0] # 계수 = 가중치
b = ransac.estimator_.intercept_ # 절편 = 편향(bias)

print(f'기울기 : {w:.3f}')
print(f'절편 : {b:.3f}')
# Out:
# 기울기 : 0.708
# 절편 : 0.041

# %%
y_linear_pred = linear.predict(X_train)
y_ransac_pred = ransac.predict(X_train)

print(np.mean( (y_test - y_linear_pred)**2 ))
print(np.mean( (y_test - y_ransac_pred)**2 ))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-44644499c14e> in <module>
#       2 y_ransac_pred = ransac.predict(X_train)
#       3
# ----> 4 print(np.mean( (y_test - y_linear_pred)**2 ))
#       5 print(np.mean( (y_test - y_ransac_pred)**2 ))
#
# ValueError: operands could not be broadcast together with shapes (102,) (404,)

# %% [markdown]
# * 정상치와 이상치 구분

# %%
inlier_mask = ransac.inlier_mask_ # 정상치 데이터 마스크
outlier_mask = np.logical_not(inlier_mask) # 이상치 데이터 마스크
inlier_mask.shape, outlier_mask.shape
# Out:
# ((404,), (404,))

# %% [markdown]
# * 정상치와 이상치 데이터 시각화

# %%
plt.scatter(X_train[inlier_mask], y_train[inlier_mask], label= 'inlier', c='dodgerblue', edgecolor='k')
plt.scatter(X_train[outlier_mask], y_train[outlier_mask], label= 'outlier', c='limegreen', edgecolor='k')
plt.plot(X_train, ransac.predict(X_train), color='r', linestyle=':', label = 'linear')  
plt.xlabel('Average number of rooms [RM] (standardized)')
plt.ylabel('Price in $1000s [MEDV] (standardized)')
plt.legend()
plt.show()

# %% [markdown]
# ### **| 회귀 성능 지표**

# %% [markdown]
# * 성능지표 함수 임포트

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %% [markdown]
# * 성능 확인을 위한 y 예측값 불러오기

# %%
y_test.shape, y_linear_pred.shape
# Out:
# ((102,), (404,))

# %% [markdown]
# #### **MSE (Mean Squared Error, 평균 제곱 오차)**
#
# \begin{split}
# \frac{1}{n} \sum^n_{i=1}(y_i - \hat{y_i})^2
# \end{split}

# %%
mean_squared_error(y_test, y_linear_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-54c59eb0c420> in <module>
# ----> 1 mean_squared_error(y_test, y_linear_pred)
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     437     """
#     438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 439         y_true, y_pred, multioutput
#     440     )
#     441     check_consistent_length(y_true, y_pred, sample_weight)
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
# --> 334             % [int(l) for l in lengths]
#     335         )
#     336
#
# ValueError: Found input variables with inconsistent numbers of samples: [102, 404]

# %% [markdown]
# #### **RMSE (Root Mean Squared Error, 제곱근 평균 제곱 오차)**
#
# \begin{split}
# \sqrt{\frac{1}{n} \sum^n_{i=1}(y_i - \hat{y_i})^2}
# \end{split}

# %%
np.sqrt(mean_squared_error(y_test, y_linear_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-7be0bf4fd3d2> in <module>
# ----> 1 np.sqrt(mean_squared_error(y_test, y_linear_pred))
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     437     """
#     438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 439         y_true, y_pred, multioutput
#     440     )
#     441     check_consistent_length(y_true, y_pred, sample_weight)
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
# --> 334             % [int(l) for l in lengths]
#     335         )
#     336
#
# ValueError: Found input variables with inconsistent numbers of samples: [102, 404]

# %% [markdown]
# #### **MAE (Mean Absolute Error, 평균 절대 오차)**
#
# \begin{split}
# \frac{1}{n} \sum^n_{i=1}|y_i - \hat{y_i}|
# \end{split}

# %%
mean_absolute_error(y_test, y_linear_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-e99ae4df598f> in <module>
# ----> 1 mean_absolute_error(y_test, y_linear_pred)
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\metrics\_regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     190     """
#     191     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 192         y_true, y_pred, multioutput
#     193     )
#     194     check_consistent_length(y_true, y_pred, sample_weight)
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
# --> 334             % [int(l) for l in lengths]
#     335         )
#     336
#
# ValueError: Found input variables with inconsistent numbers of samples: [102, 404]

# %% [markdown]
# #### **NMAE (Noramlized Mean Absolute Error, 정규화된 평균 절대 오차)**
#
# \begin{split}
# \frac{MAE}{\frac{1}{n} \sum^n_{i=1}|y_i|}
# \end{split}

# %%
def norm_mean_absolute_error(y_true, y_linear_pred):
    return mean_absolute_error(y_true, y_linear_pred)/np.mean(np.abs(y_true))
norm_mean_absolute_error(y_test, y_linear_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-5c97aff9c1f5> in <module>
#       1 def norm_mean_absolute_error(y_true, y_linear_pred):
#       2     return mean_absolute_error(y_true, y_linear_pred)/np.mean(np.abs(y_true))
# ----> 3 norm_mean_absolute_error(y_test, y_linear_pred)
#
# <ipython-input-33-5c97aff9c1f5> in norm_mean_absolute_error(y_true, y_linear_pred)
#       1 def norm_mean_absolute_error(y_true, y_linear_pred):
# ----> 2     return mean_absolute_error(y_true, y_linear_pred)/np.mean(np.abs(y_true))
#       3 norm_mean_absolute_error(y_test, y_linear_pred)
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\metrics\_regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     190     """
#     191     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 192         y_true, y_pred, multioutput
#     193     )
#     194     check_consistent_length(y_true, y_pred, sample_weight)
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
# --> 334             % [int(l) for l in lengths]
#     335         )
#     336
#
# ValueError: Found input variables with inconsistent numbers of samples: [102, 404]

# %% [markdown]
# #### **MAPE (Mean Absolute Percentage Error, 평균 절대 백분율 오차)**
#
# \begin{split}
# \frac{1}{n} \sum^n_{i=1} |\frac{y_i-\hat{y_i}}{y_i}| × 100 \
# \end{split}

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs( (y_true-y_pred) / y_true) ) * 100

mean_absolute_percentage_error(y_test, y_linear_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-3bc760e2f299> in <module>
#       3     return np.mean(np.abs( (y_true-y_pred) / y_true) ) * 100
#       4
# ----> 5 mean_absolute_percentage_error(y_test, y_linear_pred)
#
# <ipython-input-34-3bc760e2f299> in mean_absolute_percentage_error(y_true, y_pred)
#       1 def mean_absolute_percentage_error(y_true, y_pred):
#       2     y_true, y_pred = np.array(y_true), np.array(y_pred)
# ----> 3     return np.mean(np.abs( (y_true-y_pred) / y_true) ) * 100
#       4
#       5 mean_absolute_percentage_error(y_test, y_linear_pred)
#
# ValueError: operands could not be broadcast together with shapes (102,) (404,)

# %% [markdown]
# #### **SSE (Explained sum of squares)**
#
# \begin{split}
# \sum^n_{i=1} (\hat{y_i}-\bar{y})^2
# \end{split}

# %%
np.sum( ( y_test-y_linear_pred)**2 )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-43ea25d0d1be> in <module>
# ----> 1 np.sum( ( y_test-y_linear_pred)**2 )
#
# ValueError: operands could not be broadcast together with shapes (102,) (404,)

# %% [markdown]
# #### **SSR(Residual sum of squares)**
#
# \begin{split}
# \sum^n_{i=1} (y_i-\hat{y_i})^2
# \end{split}

# %%
np.sum(  (y_linear_pred-np.mean(y_test))**2  )
# Out:
# 181.87748555742644

# %% [markdown]
# #### **SST(Total sum of squares)**
#
# \begin{split}
# \sum^n_{i=1} (y_i-\bar{y_i})^2
# \end{split}

# %%
np.sum( (y_test-np.mean(y_test))**2)
# Out:
# 101.99999999999999

# %% [markdown]
# #### **결정계수 $R^2$**
# * $R^2$ 범위: 0과 1사이 존재 (값이 1에 가까울수록 성능이 좋다)
# * $R^2 = 1$: (현재 가지고 있는 x 변수로 y를 100% 설명가능) 모든 관측치가 회귀선 위에 존재
# * $R^2=0$: 현재 가지고 있는 x 변수로 y를 전혀 설명할 수 없다.
#
# \begin{split}
# R^2 = \frac{SSR}{SST} = 1-\frac{SSE}{SST}
# \end{split}

# %%
r2_score(y_test, y_linear_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-edb30e5e81bb> in <module>
# ----> 1 r2_score(y_test, y_linear_pred)
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\metrics\_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     788     """
#     789     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 790         y_true, y_pred, multioutput
#     791     )
#     792     check_consistent_length(y_true, y_pred, sample_weight)
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~\anaconda3\envs\deep_tf\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
# --> 334             % [int(l) for l in lengths]
#     335         )
#     336
#
# ValueError: Found input variables with inconsistent numbers of samples: [102, 404]

# %% [markdown]
# * 함수 정리

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
def regression_scores(y_true, y_pred):
    
    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs( (y_true-y_pred) / y_true) ) * 100
    
    a = {}
    a["MSE"] = np.round(   mean_squared_error(y_true, y_pred),3      )
    a["RMSE"] = np.round(  np.sqrt(mean_squared_error(y_true, y_pred)),3   )
    a["MAE"] = np.round(   mean_absolute_error(y_true, y_pred),3   )
    a["NMAE"] = np.round(   mean_absolute_error(y_true, y_pred)/np.mean(np.abs(y_true)),3   )
    a["MAPE"] = np.round(   mean_absolute_percentage_error(y_true, y_pred),3    )
    a["R^2"] = np.round( r2_score(y_test, y_pred), 3)
    return a

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def mean_absolute_percentage_error(y_true, y_pred):
  return np.mean(np.abs( (y_true-y_pred) / y_true) ) * 100

def norm_mean_absolute_error(y_true, y_pred):
  return mean_absolute_error(y_true, y_pred)/np.mean(np.abs(y_true))

def regression_scores(y_true,y_pred):
  mse = mean_squared_error(y_true, y_pred)
  rmse = np.sqrt(mean_squared_error(y_true, y_pred))
  mae = mean_absolute_error(y_true, y_pred)
  nmae = norm_mean_absolute_error(y_true, y_pred)
  mape = mean_absolute_percentage_error(y_true, y_pred)
  r2 = r2_score(y_true, y_pred)
  return {'mse':np.round(mse,3), 'rmse':np.round(rmse,3), 'mae':np.round(mae,3), 'nmae':np.round(nmae,3), 'mape':np.round(mape,3), 'r2':np.round(r2,3) }

# %% [markdown]
# * 함수 사용하고 데이터프레임으로 나타내기

# %%
import pandas as pd
pd.DataFrame([a])
# Out:
#     MSE   RMSE    MAE   NMAE     MAPE
# 0  0.55  0.741  0.487  0.665  234.515

# %% [markdown]
# ## 다중 회귀 분석
# ---

# %% [markdown]
# ### **| 데이터 전처리**

# %% [markdown]
# * 넘파이 배열로 변환

# %%
from Data_loader import housing_loader
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
                 'python-machine-learning-book-3rd-edition/'
                 'master/ch10/housing.data.txt',
                 header=None,
                 sep='\s+')

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 
              'NOX', 'RM', 'AGE', 'DIS', 'RAD', 
              'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.head()

X = df.iloc[:,:-1].values
y = df["MEDV"].values
X.shape, y.shape
# Out:
# ((506, 13), (506,))

# %% [markdown]
# * 데이터 분할 (테스트 비율 0.2)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((404, 13), (102, 13), (404,), (102,))

# %% [markdown]
# * 스케일링 - 정규화 진행

# %%
from sklearn.preprocessing import StandardScaler

sc_x = StandardScaler()
sc_y = StandardScaler()

sc_x.fit(X_train)
sc_y.fit( np.expand_dims(y_train, 1) )
# Out:
# StandardScaler()

# %% [markdown]
# * 훈련 데이터 정규화

# %%
X_train_scaled = sc_x.fit_transform(X_train)
y_train_scaled = sc_y.fit_transform( np.expand_dims(y_train, 1) ).flatten()

X_train_scaled.shape, y_train_scaled.shape
# Out:
# ((404, 13), (404,))

# %% [markdown]
# * 테스트 데이터 정규화

# %%
X_test_scaled = sc_x.fit_transform(X_test)
y_test_scaled = sc_y.fit_transform( np.expand_dims(y_test, 1) ).flatten()
X_test_scaled.shape, y_test_scaled.shape
# Out:
# ((102, 13), (102,))

# %% [markdown]
# ### **| 모델링**
#
# * 여러가지 회귀 모델을 사용하여 회귀 분석 진행

# %% [markdown]
# #### **Linear regression**
#
#
# \begin{split}
# \min_{w} || X w - y||_2^2
# \end{split}

# %%
from sklearn.linear_model import LinearRegression

linear = LinearRegression()
linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
linear_scaled = LinearRegression()
linear_scaled.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %% [markdown]
# #### **Ridge regression**
#
#
# \begin{split}
# \min_{w} || X w - y||_2^2 + \alpha ||w||_2^2
# \end{split}

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=0.1)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.1)

# %%
ridge_scaled = Ridge(alpha=0.1)
ridge_scaled.fit(X_train_scaled, y_train_scaled)
# Out:
# Ridge(alpha=0.1)

# %% [markdown]
# #### **Lasso regression**
#
# \begin{split}
# \min_{w} { \frac{1}{2n_{\text{samples}}} ||X w - y||_2 ^ 2 + \alpha ||w||_1}
# \end{split}

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.1)
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
lasso_scaled = Lasso(alpha=0.1)
lasso_scaled.fit(X_train_scaled, y_train_scaled)
# Out:
# Lasso(alpha=0.1)

# %% [markdown]
# #### **Elastic Net**
#
#
# \begin{split}
# \min_{w} { \frac{1}{2n_{\text{samples}}} ||X w - y||_2 ^ 2 + \alpha \rho ||w||_1 +
# \frac{\alpha(1-\rho)}{2} ||w||_2 ^ 2}
# \end{split}

# %%
from sklearn.linear_model import ElasticNet
elastic = ElasticNet(alpha =0.1)
elastic.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=0.1)

# %%
elastic_scaled = ElasticNet(alpha =0.1)
elastic_scaled.fit(X_train_scaled, y_train_scaled)
# Out:
# ElasticNet(alpha=0.1)

# %% [markdown]
# #### **Bayesian Ridge Regression**
#
#
# \begin{split}
# p(w|\lambda) =
# \mathcal{N}(w|0,\lambda^{-1}\mathbf{I}_{p})
# \end{split}

# %%
from sklearn.linear_model import BayesianRidge
bayes_ridge = BayesianRidge()
bayes_ridge.fit(X_train, y_train)
# Out:
# BayesianRidge()

# %%
bayes_ridge_scaled = BayesianRidge()
bayes_ridge_scaled.fit(X_train_scaled, y_train_scaled)
# Out:
# BayesianRidge()

# %% [markdown]
# ### **| 성능 비교**

# %% [markdown]
# * `regression_scores` 이용한 회귀 모델 성능 비교

# %%
df_score = pd.DataFrame()
for model in [ "linear", "ridge", "lasso", "elastic", "bayes_ridge"]:
    y_pred = eval(model).predict(X_test)
    scores = pd.DataFrame(regression_scores(y_test, y_pred), index=[model])
    df_score = pd.concat([df_score, scores])
df_score
# Out:
#                 mse   rmse    mae   nmae    mape     r2
# linear       23.381  4.835  3.751  0.166  18.776  0.763
# ridge        23.307  4.828  3.741  0.166  18.743  0.764
# lasso        24.716  4.972  3.772  0.167  18.959  0.750
# elastic      25.312  5.031  3.801  0.168  18.938  0.744
# bayes_ridge  24.814  4.981  3.775  0.167  18.870  0.749

# %%
df_score_scaled = pd.DataFrame()
for model in [ "linear_scaled", "ridge_scaled", "lasso_scaled", "elastic_scaled", "bayes_ridge_scaled"]:
    y_pred_scaled = eval(model).predict(X_test_scaled)
    scores = pd.DataFrame(regression_scores(y_test_scaled, y_pred_scaled), index=[model])
    df_score_scaled = pd.concat([df_score_scaled, scores])
df_score_scaled
# Out:
#                       mse   rmse    mae   nmae     mape     r2
# linear_scaled       0.222  0.471  0.362  0.521  579.145  0.778
# ridge_scaled        0.222  0.471  0.362  0.520  579.405  0.778
# lasso_scaled        0.315  0.561  0.421  0.606  549.237  0.685
# elastic_scaled      0.280  0.529  0.399  0.573  583.659  0.720
# bayes_ridge_scaled  0.220  0.469  0.359  0.516  590.402  0.780

# %% [markdown]
# * 실제값과 예측값의 산점도 그리기

# %%
for model in [ linear, ridge, lasso, elastic, bayes_ridge]:
    y_pred = model.predict(X_test)
    plt.scatter(y_test, y_pred, marker="o")
    plt.plot([0,50], [0,50])
    plt.xlabel("y_true")
    plt.ylabel("y_pred")
    plt.show()

# %%
for model in [ "linear_scaled", "ridge_scaled", "lasso_scaled", "elastic_scaled", "bayes_ridge_scaled"]:
    y_pred = eval(model).predict(X_test_scaled)
    plt.scatter(y_test_scaled, y_pred_scaled, marker="o")
    plt.plot([-3,3], [-3,3])
    plt.xlabel("y_true")
    plt.ylabel("y_pred")
    plt.show()
